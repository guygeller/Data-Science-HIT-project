# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\avivr\OneDrive\Desktop\New folder\Marvel_Dataframe_before_Dummies.csv')
df.drop(labels=["Unnamed: 0", "Name"], axis = 1, inplace = True)
df
# Out:
#       Marital Status    Reality Gender      Hair Color Eye Color  \
# 0             Single  Earth-616   Male           Brown     Green
# 1             Single  Earth-616   Male           Brown     Brown
# 2             Single      Other   Male           Black     Brown
# 3             Single      Other   Male           Brown      Blue
# 4             Single      Other   Male           Blond      Blue
# ...              ...        ...    ...             ...       ...
# 24499         Single  Earth-616   Male           Brown     Other
# 24500         Single      Other   Male           White     Other
# 24501        Married  Earth-616   Male           Black     Black
# 24502        Married  Earth-616   Male  No Hair At All     Black
# 24503         Single  Earth-616   Male           Black     Brown
#
#       Living status Identity Citenzenship  Year  Appearnces
# 0             Alive  No Dual     American  2018           3
# 1             Alive  No Dual        Other  1976          12
# ...

# %%
df['Gender'].value_counts().plot(kind = 'pie', shadow=True, wedgeprops = {"edgecolor" : "black",'linewidth': 1})
# Out:
# <AxesSubplot:ylabel='Gender'>

# %%
df['Marital Status'].value_counts().plot(kind = 'pie', shadow=True, wedgeprops = {"edgecolor" : "black",'linewidth': 1})
# Out:
# <AxesSubplot:ylabel='Marital Status'>

# %%
df['Citenzenship'].value_counts().plot(kind = 'pie', shadow=True, wedgeprops = {"edgecolor" : "black",'linewidth': 1})
# Out:
# <AxesSubplot:ylabel='Citenzenship'>

# %%
df['Reality'].value_counts().plot(kind = 'pie', shadow=True, wedgeprops = {"edgecolor" : "black",'linewidth': 1})
# Out:
# <AxesSubplot:ylabel='Reality'>

# %%
df['Living status'].value_counts().plot(kind = 'pie', shadow=True, wedgeprops = {"edgecolor" : "black",'linewidth': 1})
# Out:
# <AxesSubplot:ylabel='Living status'>

# %%
df['Identity'].value_counts().plot(kind = 'pie', shadow=True, wedgeprops = {"edgecolor" : "black",'linewidth': 1})
# Out:
# <AxesSubplot:ylabel='Identity'>

# %%
# HISTOGRAM FOR CONTINOUS VARIABLES 
df['Appearnces'] = np.log(df.Appearnces)
hist_graph = df.hist(bins=25, layout=(2,3), figsize=(15,15),column =['Year','Appearnces'])

# %%
sns.catplot(x='Gender', y='Appearnces', data=df, kind='box')

# %%
sns.catplot(x='Marital Status', y='Appearnces', data=df, kind='box')

# %%
sns.catplot(x='Reality', y='Appearnces', data=df, kind='box')

# %%
sns.catplot(x='Gender', y='Appearnces', data=df, kind='box')

# %%
sns.catplot(x='Hair Color', y='Appearnces', data=df, kind='box', height=5, aspect=2)

# %%
sns.catplot(x='Eye Color', y='Appearnces', data=df, kind='box')

# %%
sns.catplot(x='Living status', y='Appearnces', data=df, kind='box')

# %%
sns.catplot(x='Identity', y='Appearnces', data=df, kind='box')

# %%
sns.catplot(x='Citenzenship', y='Appearnces', data=df, kind='box')
